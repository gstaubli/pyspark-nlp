# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /home/nbuser/anaconda3_501/lib/python3.6/site-packages
# Requirement already satisfied: py4j==0.10.4 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pyspark)

# %%
# !wget --no-verbose http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Clothing_Shoes_and_Jewelry_5.json.gz
# Out:
# 2018-02-20 03:42:29 URL:http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Clothing_Shoes_and_Jewelry_5.json.gz [47285200/47285200] -> "reviews_Clothing_Shoes_and_Jewelry_5.json.gz" [1]

# %% [markdown]
# +/- Effect Lexicon http://mpqa.cs.pitt.edu/lexicons/effect_lexicon/

# %%
# !wget --no-verbose http://mpqa.cs.pitt.edu/data/effectwordnet.zip
# Out:
# 2018-02-20 04:30:50 URL:http://mpqa.cs.pitt.edu/data/effectwordnet.zip [528829/528829] -> "effectwordnet.zip" [1]

# %%
# !unzip effectwordnet.zip
# Out:
# Archive:  effectwordnet.zip
#    creating: effectwordnet/
#   inflating: effectwordnet/EffectWordNet.tff
#   inflating: effectwordnet/goldStandard.tff
#   inflating: effectwordnet/README

# %%
import sys
sys.path.insert(0, "../")
from garrens_utils import *
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
from pyspark.ml import Pipeline, PipelineModel
from sparknlp.annotator import *
from sparknlp.base import DocumentAssembler, Finisher

# %%
reviews = spark.read.json("../data/input/reviews_Clothing_Shoes_and_Jewelry_5.json.gz")
reviews.cache().count() # FAST is GOOD
reviews.createOrReplaceTempView("reviews")

# %%
reviews.printSchema()
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- helpful: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- overall: double (nullable = true)
#  |-- reviewText: string (nullable = true)
#  |-- reviewTime: string (nullable = true)
#  |-- reviewerID: string (nullable = true)
#  |-- reviewerName: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- unixReviewTime: long (nullable = true)

# %%
# %%sql_display
# SELECT *
# FROM reviews
# ORDER BY RAND()
# Out:
#           asin helpful  overall  \
# 0   B0057D57NK  [0, 0]      5.0
# 1   B000PHI5L4  [6, 7]      4.0
# 2   B000W4IGHS  [0, 0]      5.0
# 3   B003DIPCC2  [0, 1]      5.0
# 4   B001VEIDBW  [2, 2]      5.0
# 5   B008J9Z310  [0, 0]      5.0
# 6   B000OCSJN4  [0, 0]      5.0
# 7   B0059DSSEI  [0, 0]      4.0
# 8   B000T9VK56  [0, 0]      2.0
# 9   B00DV19WBS  [0, 0]      5.0
# 10  B00450WQMG  [1, 2]      1.0
# 11  B000M9JJ7O  [0, 0]      4.0
# 12  B00E06CTLS  [0, 0]      4.0
# 13  B0085ITMRG  [0, 0]      5.0
# 14  B008HOJRUK  [0, 0]      5.0
# 15  B0084FZQI4  [0, 0]      4.0
# 16  B00AQ9GWTS  [3, 4]      3.0
# 17  B00GZYJSEO  [0, 0]      5.0
# 18  B008N6ZIM8  [0, 0]      5.0
# 19  B0000B35D8  [0, 0]      5.0
# 20  B003J36RTS  [1, 1]      5.0
# 21  B000JVMG4I  [0, 0]      4.0
# 22  B003N63ESI  [0, 0]      4.0
# 23  B007WA2Q5I  [0, 0]      5.0
# 24  B008GU8DJ6  [0, 0]      4.0
# 25  B005CKQ3C2  [0, 0]      4.0
# 26  B0023RSKL4  [0, 0]      5.0
# 27  B0001455AU  [0, 0]      3.0
# 28  B00F3IDBZA  [1, 1]      5.0
# 29  B0028NW15E  [2, 2]      5.0
# 30  B0000ANHST  [0, 0]      5.0
# 31  B00C0NFCBC  [7, 7]      2.0
# 32  B004LVXYIO  [0, 0]      5.0
# 33  B00CAMCNQ0  [0, 0]      5.0
# 34  B0032JEGAQ  [6, 6]      5.0
# 35  B002WN183Q  [0, 1]      5.0
# 36  B002C9K9EY  [2, 3]      5.0
# 37  B003TM4SH2  [0, 0]      5.0
# 38  B000EZT5GG  [0, 0]      3.0
# 39  B00CEM3XPQ  [0, 0]      5.0
# 40  B004I75NK8  [1, 1]      4.0
# 41  B0031U0NVC  [0, 0]      5.0
# 42  B008WYDI7I  [0, 0]      3.0
# 43  B00IT3GL94  [0, 0]      2.0
# 44  B00IK0WG36  [3, 3]      5.0
# 45  B00BTQR0AC  [0, 1]      5.0
# 46  B00AMWGB3G  [1, 2]      5.0
# 47  B000H8250S  [0, 0]      5.0
# 48  B000EXPSZU  [0, 0]      5.0
# 49  B000YAD3PU  [1, 1]      4.0
#
#                                            reviewText   reviewTime  \
# 0   This is pretty! The color was slightly differe...  02 26, 2014
# 1   I ordered the 3XL and despite my size, there i...  08 14, 2012
# 2   Got this as a surprise anniversary gift. It is...  06 20, 2014
# 3   el reloj esta bastante bien para el precio lo ...  07 23, 2012
# 4   A perfect length and they stay up (unlike most...  08 15, 2012
# 5   These glasses are well made, they came in a ni...  01 15, 2014
# 6   These are super comfortable Birks. Perfect for...  01 12, 2013
# 7   Fit is great and I love the color! Not as warm...   03 9, 2014
# 8   some of these parts are really cheap and pract...   02 7, 2014
# 9   this robe is so soft and fluffy and comfortabl...  02 21, 2014
# 10  I bought this and a few other dresses from thi...  04 15, 2014
# 11  I had a problem finding running pants for my h...  01 23, 2013
# 12  good quality, better as we expected to a gift ...   02 7, 2014
# 13  We own several zutano items. All are of excell...  05 28, 2013
# 14  Goes with skirts, dresses, and slacks. Very cl...  09 21, 2013
# 15  I wear Bali all the time, this bra fits true t...  03 19, 2014
# 16  just a little to narrow.  i sent them back.  r...  11 19, 2013
# 17  Absolutely beautiful. I have the Mint Glitter ...   03 3, 2014
# 18  GREAT STYLE AND COLOR WARM Conford 100% LEATHE...   03 9, 2014
# 19  Very small but great for a small child.  Beaut...   02 2, 2013
# 20  These are not duddy looking slippers--these sl...  11 18, 2012
# 21  This comes with a lot of entertaining things t...  11 13, 2010
# 22  These are comfortable and a nice fit.  Not too...  10 22, 2013
# 23  The printed tank top underneath is soft, cute,...  02 28, 2013
# 41                                      great product      1363996800
# 42                          The outfit is attractive.      1398902400
# 43                              Had to send them back      1400889600
# 44                                         Nice Tunic      1401148800
# 45                                  Does what it says      1372204800
# 46                               Comfortable and Cute      1367884800
# 47                                      Good backpack      1371081600
# 48                                      rockport mens      1379721600
# 49                                       Does the job      1392076800

# %%
print("Unique Items: {items}".format(items=reviews.select("asin").distinct().count()))
print("Reviews per Item:")
reviews.groupBy("asin").count().select("count").describe().show()
# Out:
# Unique Items: 23033
# Reviews per Item:
# +-------+------------------+
# |summary|             count|
# +-------+------------------+
# |  count|             23033|
# |   mean|12.099031823904832|
# | stddev|13.968255188902537|
# |    min|                 5|
# |    max|               441|
# +-------+------------------+

# %%
gold_sent = spark.read\
                .option("inferSchema","true")\
                .option("sep","\t")\
                .csv("../data/input/effectwordnet/goldStandard.tff")\
                .toDF("synset_offset", "sent_type", "synset", "gloss")

# %%
rest_sent = spark.read\
                .option("inferSchema","true")\
                .option("sep","\t")\
                .csv("../data/input/effectwordnet/EffectWordNet.tff")\
                .toDF("synset_offset", "sent_type", "synset", "gloss")

# %% [markdown]
# ### ETL positive and negative words

# %%
gold_words = gold_sent.select("sent_type", F.explode(F.split("synset",",")).alias("word"))
gold_negative_words = gold_words.filter("sent_type = '-Effect'").select("word")
gold_positive_words = gold_words.filter("sent_type = '+Effect'").select("word")

rest_words = rest_sent.select("sent_type", F.explode(F.split("synset",",")).alias("word"))
rest_negative_words = rest_words.filter("sent_type = '-Effect'").select("word")
rest_positive_words = rest_words.filter("sent_type = '+Effect'").select("word")

negative_words = gold_negative_words.union(rest_negative_words).distinct()
positive_words = gold_positive_words.union(rest_positive_words).distinct()

# %%
negative_words.toPandas().to_csv("../data/input/negative_words.csv",index=False,header=False)
positive_words.toPandas().to_csv("../data/input/positive_words.csv",index=False,header=False)

# %% [markdown]
# ### Spark NLP Estimators and Transformers

# %%
document_assembler = DocumentAssembler() \
            .setInputCol("reviewText")

sentence_detector = SentenceDetector() \
    .setInputCols(["document"]) \
    .setOutputCol("sentence")
    
tokenizer = Tokenizer() \
            .setInputCols(["sentence"]) \
            .setOutputCol("token")
        
normalizer = Normalizer() \
            .setInputCols(["token"]) \
            .setOutputCol("normal")
        
spell_checker = NorvigSweetingApproach() \
            .setInputCols(["normal"]) \
            .setOutputCol("spell")
        
sentiment_detector = ViveknSentimentApproach() \
    .setInputCols(["spell", "sentence"]) \
    .setOutputCol("sentiment") \
    .setPruneCorpus(0) \
    .setPositiveSource("../data/input/positive_words.csv") \
    .setNegativeSource("../data/input/negative_words.csv")
        
finisher = Finisher() \
    .setInputCols(["sentiment"]) \
    .setIncludeKeys(True)
        
pipeline = Pipeline(stages=[
    document_assembler,
    sentence_detector,
    tokenizer,
    normalizer,
    spell_checker,
    sentiment_detector,
    finisher
])

# %% [markdown]
# ### Run Estimators and Transformers to train and apply model respectively

# %%
start = time.time()
sentiment_data = pipeline.fit(reviews).transform(reviews.sort(F.rand()).limit(1000))
end = time.time()
print("Time elapsed pipeline process: " + str(end - start))
# Out:
# +----------+-------+-------+--------------------+-----------+--------------+--------------------+--------------------+--------
# |0000031887| [0, 0]|    1.0|Never GOT this it...|05 12, 2014|A2XJ13PIXVJFJH| Myra MLH "Myra MLH"|    Never GOT IT....|    1399852800|result->negative@...|
# |0000031887| [0, 0]|    5.0|Nice and puffy tu...|12 24, 2013|A287XY94U7JDM8|             Natasha|          Nice skirt|    1387843200|result->negative@...|
# |0000031887| [0, 0]|    5.0|Bought this for m...|01 30, 2013|A1JR9KKF6UKUWW|       Queens Meadow|must have for a f...|    1359504000|result->negative@...|
# +----------+-------+-------+--------------------+-----------+--------------+--------------------+--------------------+--------------+--------------------+
# only showing top 20 rows
#
# Time elapsed pipeline process: 339.81911754608154

# %%
sentimentalized = spark.read.parquet("../data/output/sentimentalized_10k/")
sentimentalized.createOrReplaceTempView("sentimentalized")

# %% [markdown]
# ### Confirm sample is representative of population

# %%
# %%sql_display
# SELECT overall, COUNT(1), ROUND(COUNT(1)/(SELECT COUNT(1) FROM sentimentalized),2) AS pct_total
# FROM sentimentalized
# GROUP BY overall
# ORDER BY overall ASC
# Out:
#    overall  count(1)  pct_total
# 0      1.0       441       0.04
# 1      2.0       534       0.05
# 2      3.0      1058       0.11
# 3      4.0      2100       0.21
# 4      5.0      5867       0.59

# %%
# %%sql_display
# SELECT overall, COUNT(1), ROUND(COUNT(1)/(SELECT COUNT(1) FROM reviews),2) AS pct_total
# FROM reviews
# GROUP BY overall
# ORDER BY overall ASC
# Out:
#    overall  count(1)  pct_total
# 0      1.0     11192       0.04
# 1      2.0     15463       0.06
# 2      3.0     30425       0.11
# 3      4.0     58357       0.21
# 4      5.0    163240       0.59

# %%
from pyspark.sql.functions import udf

# %% [markdown]
# Given an array of sentence sentiments, calculate ratio of positivity

# %%
@udf
def sentiment_ratio(sentiment_result_array): 
    positives = [s for s in sentiment_result_array if s == 'positive']
    sentiment_count = len(sentiment_result_array)
    return round(len(positives)/sentiment_count,1)

# %% [markdown]
# #### Break down sentence sentiments by ratio of positivity

# %%
sentenced_to_sentimentalization = sentimentalized.select(
    F.col("overall"), 
    F.split(
        F.regexp_replace("finished_sentiment", "result->", "")
    , "@").alias("split_sentiments")
)\
.withColumn("num_sentences", F.size("split_sentiments"))\
.withColumn("sentiment_ratio", sentiment_ratio(F.col("split_sentiments")))\
.withColumn("first_sentiment", F.expr("split_sentiments[0]"))\
.withColumn("last_sentiment", F.expr("split_sentiments[num_sentences-1]"))

# %%
sentenced_to_sentimentalization.createOrReplaceTempView("sentencing")

# %%
# %%sql_display
# SELECT overall, AVG(sentiment_ratio) AS avg_sent_ratio, AVG(num_sentences)
# FROM sentencing
# GROUP BY overall
# ORDER BY overall
# Out:
#    overall  avg_sent_ratio  avg(num_sentences)
# 0      1.0        0.590703            4.519274
# 1      2.0        0.615918            4.507491
# 2      3.0        0.639225            3.943289
# 3      4.0        0.674190            4.126190
# 4      5.0        0.720112            4.130220
